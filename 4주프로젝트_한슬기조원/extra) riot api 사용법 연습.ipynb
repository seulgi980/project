# %%
import requests
url = 'https://kr.api.riotgames.com/lol/league/v4/challengerleagues/by-queue/RANKED_SOLO_5x5'

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36",
    "Accept-Language": "ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7",
    "Accept-Charset": "application/x-www-form-urlencoded; charset=UTF-8",
    "Origin": "https://developer.riotgames.com",
    "X-Riot-Token": "RGAPI-9ad63f55-822e-470f-9019-73cffaa12ae3"
}

response = requests.get(url, headers = headers)

response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'tier': 'CHALLENGER',
#  'leagueId': '70d8c920-e79e-383e-b905-f8e94c2955d2',
#  'queue': 'RANKED_SOLO_5x5',
#  'name': "Teemo's Crusaders",
#  'entries': [{'summonerId': 'PDNhaimjcMnhEkkeRNBqNwxJfCPXJMfHBB6YVPtcptcFlYM',
#    'summonerName': '칼과 창 방패',
#    'leaguePoints': 567,
#    'rank': 'I',
#    'wins': 62,
#    'losses': 43,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': '8gggGcS8cbKbXV1PIY_Bjb_dSVquulS_kEDNqoz1R6M5pIQ',
#    'summonerName': 'KT Way',
#    'leaguePoints': 581,
#    'rank': 'I',
#    'wins': 49,
#    'losses': 27,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'JfZHKyNrWcXyCws3b2M0icZL74kQBpf8GFTItnDEXul9Fz8',
#    'summonerName': '콜럼버스 애디',
#    'leaguePoints': 550,
#    'rank': 'I',
#    'wins': 62,
#    'losses': 46,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
# ...

# %%
# 유저정보
import requests
username = 'hide on bush'
url = f'https://kr.api.riotgames.com/lol/summoner/v4/summoners/by-name/{username}'

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36",
    "Accept-Language": "ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7",
    "Accept-Charset": "application/x-www-form-urlencoded; charset=UTF-8",
    "Origin": "https://developer.riotgames.com",
    "X-Riot-Token": "RGAPI-bb4d1491-f510-425e-95fe-8ad2094f6e2d"
}
response = requests.get(url, headers = headers)

response
# Out:
# <Response [200]>

# %%
result = response.json()
result
# Out:
# {'id': 'nXGINksmuX1mVStjwL-yjx617eLKbPQbZVuHma49SNULCg',
#  'accountId': 'IbOp0e6OtCKib7mnyNkwQW6ke1UWBSoyIFI8jHvsOePr',
#  'puuid': 'vqnoBCoL6J3OBAQNfakAGjXCb1bYyOxRdvxQlROJGBPJO2veYIIIkDHNLC2rM4WaFegdV8XCNkDIHQ',
#  'name': 'Hide on bush',
#  'profileIconId': 6,
#  'revisionDate': 1673979917317,
#  'summonerLevel': 621}

# %%
# 유저ID로 경기20개
import requests

puuid = "vqnoBCoL6J3OBAQNfakAGjXCb1bYyOxRdvxQlROJGBPJO2veYIIIkDHNLC2rM4WaFegdV8XCNkDIHQ"

url = f"https://asia.api.riotgames.com/lol/match/v5/matches/by-puuid/{puuid}/ids?start=0&count=20"

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36",
    "Accept-Language": "ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7",
    "Accept-Charset": "application/x-www-form-urlencoded; charset=UTF-8",
    "Origin": "https://developer.riotgames.com",
    "X-Riot-Token": "RGAPI-bb4d1491-f510-425e-95fe-8ad2094f6e2d"
}
response = requests.get(url, headers=headers)
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# ['KR_6314257119',
#  'KR_6314209518',
#  'KR_6314166923',
#  'KR_6314133155',
#  'KR_6314075186',
#  'KR_6313224933',
#  'KR_6313178546',
#  'KR_6312556156',
#  'KR_6312511022',
#  'KR_6310758808',
#  'KR_6310715102',
#  'KR_6310656435',
#  'KR_6310591134',
#  'KR_6310501882',
#  'KR_6309550027',
#  'KR_6308555434',
#  'KR_6308512414',
#  'KR_6308416982',
#  'KR_6308370571',
#  'KR_6308296037']

# %%
# 경기 ID로 경기정보찾기
# 타림라인 들어간거
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36",
    "Accept-Language": "ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7",
    "Accept-Charset": "application/x-www-form-urlencoded; charset=UTF-8",
    "Origin": "https://developer.riotgames.com",
    "X-Riot-Token": "RGAPI-bb4d1491-f510-425e-95fe-8ad2094f6e2d"
}
matchid = 'KR_6314257119'

url = f'https://asia.api.riotgames.com/lol/match/v5/matches/{matchid}/timeline'

response = requests.get(url, headers=headers)
response
# Out:
# <Response [200]>

# %%
response.json().keys()
# Out:
# dict_keys(['metadata', 'info'])

# %%
response.json()['info'].keys()
# Out:
# dict_keys(['frameInterval', 'frames', 'gameId', 'participants'])

# %%
response.json()['info']['frames'][0]
# Out:
# {'events': [{'realTimestamp': 1673979046015,
#    'timestamp': 0,
#    'type': 'PAUSE_END'}],
#  'participantFrames': {'1': {'championStats': {'abilityHaste': 0,
#     'abilityPower': 0,
#     'armor': 33,
#     'armorPen': 0,
#     'armorPenPercent': 0,
#     'attackDamage': 25,
#     'attackSpeed': 100,
#     'bonusArmorPenPercent': 0,
#     'bonusMagicPenPercent': 0,
#     'ccReduction': 0,
#     'cooldownReduction': 0,
#     'health': 610,
#     'healthMax': 610,
#     'healthRegen': 0,
#     'lifesteal': 0,
#     'magicPen': 0,
#     'magicPenPercent': 0,
#     'magicResist': 30,
#     'movementSpeed': 330,
#     'omnivamp': 0,
#     'physicalVamp': 0,
#     'power': 290,
#     'powerMax': 290,
#     'powerRegen': 0,
#     'spellVamp': 0},
#    'currentGold': 500,
#    'damageStats': {'magicDamageDone': 0,
#     'magicDamageDoneToChampions': 0,
#     'magicDamageTaken': 0,
#     'physicalDamageDone': 0,
#     'physicalDamageDoneToChampions': 0,
#     'physicalDamageTaken': 0,
# ...

# %%
response.json()['info']['frames'][0]['participantFrames']['10']
# Out:
# {'championStats': {'abilityHaste': 0,
#   'abilityPower': 0,
#   'armor': 39,
#   'armorPen': 0,
#   'armorPenPercent': 0,
#   'attackDamage': 25,
#   'attackSpeed': 100,
#   'bonusArmorPenPercent': 0,
#   'bonusMagicPenPercent': 0,
#   'ccReduction': 0,
#   'cooldownReduction': 0,
#   'health': 646,
#   'healthMax': 646,
#   'healthRegen': 0,
#   'lifesteal': 0,
#   'magicPen': 0,
#   'magicPenPercent': 0,
#   'magicResist': 32,
#   'movementSpeed': 325,
#   'omnivamp': 0,
#   'physicalVamp': 0,
#   'power': 400,
#   'powerMax': 400,
#   'powerRegen': 0,
#   'spellVamp': 0},
#  'currentGold': 500,
#  'damageStats': {'magicDamageDone': 0,
#   'magicDamageDoneToChampions': 0,
#   'magicDamageTaken': 0,
#   'physicalDamageDone': 0,
#   'physicalDamageDoneToChampions': 0,
#   'physicalDamageTaken': 0,
#   'totalDamageDone': 0,
#   'totalDamageDoneToChampions': 0,
#   'totalDamageTaken': 0,
#   'trueDamageDone': 0,
#   'trueDamageDoneToChampions': 0,
#   'trueDamageTaken': 0},
# ...

# %%
# 10명의 유저 정보
response.json()['info']['participants']
# Out:
# [{'participantId': 1,
#   'puuid': 'af_61zNLYyrjbYKsURVvkXy-FynGEOvyN1U7TK4xBDh9TfpFj6YcxxS1FWlqxn4jZwv1YV40UmKPIQ'},
#  {'participantId': 2,
#   'puuid': 'rl3nyLA5dwvs55E60DnAZDaC13f1j95sKeo4XuPln2hD6XygIxIJQQ1X2C3zpZpnFq-WYrH9iypD0g'},
#  {'participantId': 3,
#   'puuid': 'z9gVQSAYfap6imIrOH5OhEgCehyZ5d4KRpO9awD9eS_Z_jVMj7wYaI-GqNTHiO8jBlmiDcQPA_QCdQ'},
#  {'participantId': 4,
#   'puuid': '_AQxnKFR3HZcDt8zyV-hmtDT-zImT0-q3HrX1WeOfahao63QjYov9D_Tr3q_rT1AfY67RfLQfYmxAA'},
#  {'participantId': 5,
#   'puuid': 'BJkzEDwFk5njJ2g-x-gYkosOM-cEMTtFAzOP6aNsHUIIMR8BU0OQ7hTr5l6pzChnyigbAZKqZytTQQ'},
#  {'participantId': 6,
#   'puuid': 'RySHhoqYnN_y3WrAbBNmWU8AuozM_kXrMlxoS-1gudo5QCaEOahaurqWK4Z1XT7EUWk5CFXkGH1MYg'},
#  {'participantId': 7,
#   'puuid': 'QnAO9Fm26StL-4Fo7hsl3MoTKPBCqUWnjVkuNeGKsEV7XHEQuKA5hJmVmcp9i3RJux_wdJZFZc-hKg'},
#  {'participantId': 8,
#   'puuid': 'vqnoBCoL6J3OBAQNfakAGjXCb1bYyOxRdvxQlROJGBPJO2veYIIIkDHNLC2rM4WaFegdV8XCNkDIHQ'},
#  {'participantId': 9,
# ...

# %% [markdown]
# # 재혁님여기서부터요1!!!⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐

# %%
# 타임라인 안붙은거

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36",
    "Accept-Language": "ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7",
    "Accept-Charset": "application/x-www-form-urlencoded; charset=UTF-8",
    "Origin": "https://developer.riotgames.com",
    "X-Riot-Token": "RGAPI-bb4d1491-f510-425e-95fe-8ad2094f6e2d"
}

matchid = 'KR_6314257119'

url = f'https://asia.api.riotgames.com/lol/match/v5/matches/{matchid}'

response = requests.get(url, headers=headers)
response
# Out:
# <Response [200]>

# %%
response.json().keys()
# Out:
# dict_keys(['metadata', 'info'])

# %%
response.json()['info'].keys()
# Out:
# dict_keys(['gameCreation', 'gameDuration', 'gameEndTimestamp', 'gameId', 'gameMode', 'gameName', 'gameStartTimestamp', 'gameType', 'gameVersion', 'mapId', 'participants', 'platformId', 'queueId', 'teams', 'tournamentCode'])

# %%
response.json()['info']['participants'][0]
# Out:
# {'allInPings': 0,
#  'assistMePings': 0,
#  'assists': 3,
#  'baitPings': 0,
#  'baronKills': 0,
#  'basicPings': 0,
#  'bountyLevel': 0,
#  'challenges': {'12AssistStreakCount': 0,
#   'abilityUses': 292,
#   'acesBefore15Minutes': 0,
#   'alliedJungleMonsterKills': 0,
#   'baronTakedowns': 0,
#   'blastConeOppositeOpponentCount': 0,
#   'bountyGold': 150,
#   'buffsStolen': 0,
#   'completeSupportQuestInTime': 0,
#   'controlWardTimeCoverageInRiverOrEnemyHalf': 0.020747119451505744,
#   'controlWardsPlaced': 2,
#   'damagePerMinute': 733.9930993859322,
#   'damageTakenOnTeamPercentage': 0.2427608494708223,
#   'dancedWithRiftHerald': 0,
#   'deathsByEnemyChamps': 8,
#   'dodgeSkillShotsSmallWindow': 14,
#   'doubleAces': 0,
#   'dragonTakedowns': 0,
#   'earlyLaningPhaseGoldExpAdvantage': 0,
#   'effectiveHealAndShielding': 320.3385009765625,
#   'elderDragonKillsWithOpposingSoul': 0,
#   'elderDragonMultikills': 0,
#   'enemyChampionImmobilizations': 72,
# ...

# %%
response.json()['info']['participants'][0]
# Out:
# {'allInPings': 0,
#  'assistMePings': 0,
#  'assists': 3,
#  'baitPings': 0,
#  'baronKills': 0,
#  'basicPings': 0,
#  'bountyLevel': 0,
#  'challenges': {'12AssistStreakCount': 0,
#   'abilityUses': 292,
#   'acesBefore15Minutes': 0,
#   'alliedJungleMonsterKills': 0,
#   'baronTakedowns': 0,
#   'blastConeOppositeOpponentCount': 0,
#   'bountyGold': 150,
#   'buffsStolen': 0,
#   'completeSupportQuestInTime': 0,
#   'controlWardTimeCoverageInRiverOrEnemyHalf': 0.020747119451505744,
#   'controlWardsPlaced': 2,
#   'damagePerMinute': 733.9930993859322,
#   'damageTakenOnTeamPercentage': 0.2427608494708223,
#   'dancedWithRiftHerald': 0,
#   'deathsByEnemyChamps': 8,
#   'dodgeSkillShotsSmallWindow': 14,
#   'doubleAces': 0,
#   'dragonTakedowns': 0,
#   'earlyLaningPhaseGoldExpAdvantage': 0,
#   'effectiveHealAndShielding': 320.3385009765625,
#   'elderDragonKillsWithOpposingSoul': 0,
#   'elderDragonMultikills': 0,
#   'enemyChampionImmobilizations': 72,
# ...

# %%
response.json()['info']['participants'][0]['kills']
# Out:
# 2

# %%
response.json()['info']['participants'][0]['deaths']
# Out:
# 8

# %%
response.json()['info']['participants'][0]['assists']
# Out:
# 3

# %%
response.json()['info']['participants'][0]['goldEarned']
# Out:
# 9280

# %%
response.json()['info']['participants'][0]['lane']
# Out:
# 'TOP'

# %%
response.json()['info']['participants'][0]['totalDamageDealtToChampions']
# Out:
# 18075

# %%
response.json()['info']['participants'][0]['champLevel']
# 레벨 상대챔프와 레벨차이 계산해야함.(겜끝났을때 레벨차이 18/18은제외)
# Out:
# 13

# %%
response.json()['info']['participants'][0]['championName']
# Out:
# 'KSante'

# %%
# 다시하기 유무 다시하기는 데이터에서 제외
response.json()['info']['participants'][0]['gameEndedInEarlySurrender']
# Out:
# False

# %%
response.json()['info']['participants'][0]['lane']
# Out:
# 'TOP'
