# %% [markdown]
# # 챔피언사진가져오기

# %%
champion_name_eng = ['Aatrox', 'Ahri', 'Akali', 'Akshan', 'Alistar', 'Amumu', 'Anivia', 'Annie', 'Aphelios', 'Ashe', 'AurelionSol', 'Azir', 'Bard', 'Belveth', 'Blitzcrank', 'Brand', 'Braum', 'Caitlyn', 'Camille', 'Cassiopeia', 'Chogath', 'Corki', 'Darius', 'Diana', 'Draven', 'DrMundo', 'Ekko', 'Elise', 'Evelynn', 'Ezreal', 'Fiddlesticks', 'Fiora', 'Fizz', 'Galio', 'Gangplank', 'Garen', 'Gnar', 'Gragas', 'Graves', 'Gwen', 'Hecarim', 'Heimerdinger', 'Illaoi', 'Irelia', 'Ivern', 'Janna', 'JarvanIV', 'Jax', 'Jayce', 'Jhin', 'Jinx', 'Kaisa', 'Kalista', 'Karma', 'Karthus', 'Kassadin', 'Katarina', 'Kayle', 'Kayn', 'Kennen', 'Khazix', 'Kindred', 'Kled', 'KogMaw', 'KSante', 'Leblanc', 'LeeSin', 'Leona', 'Lillia', 'Lissandra', 'Lucian', 'Lulu', 'Lux', 'Malphite', 'Malzahar', 'Maokai', 'MasterYi', 'MissFortune', 'MonkeyKing', 'Mordekaiser', 'Morgana', 'Nami', 'Nasus', 'Nautilus', 'Neeko', 'Nidalee', 'Nilah', 'Nocturne', 'Nunu', 'Olaf', 'Orianna', 'Ornn', 'Pantheon', 'Poppy', 'Pyke', 'Qiyana', 'Quinn', 'Rakan', 'Rammus', 'RekSai', 'Rell', 'Renata', 'Renekton', 'Rengar', 'Riven', 'Rumble', 'Ryze', 'Samira', 'Sejuani', 'Senna', 'Seraphine', 'Sett', 'Shaco', 'Shen', 'Shyvana', 'Singed', 'Sion', 'Sivir', 'Skarner', 'Sona', 'Soraka', 'Swain', 'Sylas', 'Syndra', 'TahmKench', 'Taliyah', 'Talon', 'Taric', 'Teemo', 'Thresh', 'Tristana', 'Trundle', 'Tryndamere', 'TwistedFate', 'Twitch', 'Udyr', 'Urgot', 'Varus', 'Vayne', 'Veigar', 'Velkoz', 'Vex', 'Vi', 'Viego', 'Viktor', 'Vladimir', 'Volibear', 'Warwick', 'Xayah', 'Xerath', 'XinZhao', 'Yasuo', 'Yone', 'Yorick', 'Yuumi', 'Zac', 'Zed', 'Zeri', 'Ziggs', 'Zilean', 'Zoe', 'Zyra']

# %%
# 폴더만들고
import os
for cham_name in champion_name_eng:
  os.mkdir('/content/drive/MyDrive/4주프로젝트/champion_img1/{}'.format(cham_name))

# %%
from urllib.request import urlretrieve
for cham_name in champion_name_eng:
  urlretrieve("https://ddragon.leagueoflegends.com/cdn/13.1.1/img/champion/{}.png".format(cham_name), '/content/drive/MyDrive/4주프로젝트/champion_img1/{}/{}.jpg'.format(cham_name, cham_name))

# %% [markdown]
# # 아이템사진가져오기

# %%
import json

with open('/content/item.json', 'r') as f:
  item_json = json.load(f)
  
item_json
# Out:
# {'type': 'item',
#  'version': '13.3.1',
#  'basic': {'name': '',
#   'rune': {'isrune': False, 'tier': 1, 'type': 'red'},
#   'gold': {'base': 0, 'total': 0, 'sell': 0, 'purchasable': False},
#   'group': '',
#   'description': '',
#   'colloq': ';',
#   'plaintext': '',
#   'consumed': False,
#   'stacks': 1,
#   'depth': 1,
#   'consumeOnFull': False,
#   'from': [],
#   'into': [],
#   'specialRecipe': 0,
#   'inStore': True,
#   'hideFromAll': False,
#   'requiredChampion': '',
#   'requiredAlly': '',
#   'stats': {'FlatHPPoolMod': 0,
#    'rFlatHPModPerLevel': 0,
#    'FlatMPPoolMod': 0,
#    'rFlatMPModPerLevel': 0,
#    'PercentHPPoolMod': 0,
#    'PercentMPPoolMod': 0,
#    'FlatHPRegenMod': 0,
#    'rFlatHPRegenModPerLevel': 0,
#    'PercentHPRegenMod': 0,
#    'FlatMPRegenMod': 0,
#    'rFlatMPRegenModPerLevel': 0,
#    'PercentMPRegenMod': 0,
#    'FlatArmorMod': 0,
#    'rFlatArmorModPerLevel': 0,
#    'PercentArmorMod': 0,
#    'rFlatArmorPenetrationMod': 0,
# ...

# %%
item_json.keys()
# Out:
# dict_keys(['type', 'version', 'basic', 'data', 'groups', 'tree'])

# %%
item_json['data'].keys()
# Out:
# dict_keys(['1001', '1004', '1006', '1011', '1018', '1026', '1027', '1028', '1029', '1031', '1033', '1035', '1036', '1037', '1038', '1039', '1040', '1042', '1043', '1052', '1053', '1054', '1055', '1056', '1057', '1058', '
# %%
item_name_eng = []
for idx in lst:
  item_name_eng.append(item_json['data'][idx]['name'])

# %%
item_name_eng
# Out:
# ['Boots',
#  'Faerie Charm',
#  'Rejuvenation Bead',
#  "Giant's Belt",
#  'Cloak of Agility',
#  'Blasting Wand',
#  'Sapphire Crystal',
#  'Ruby Crystal',
#  'Cloth Armor',
#  'Chain Vest',
#  'Null-Magic Mantle',
#  'Emberknife',
#  'Long Sword',
#  'Pickaxe',
#  'B. F. Sword',
#  'Hailblade',
#  'Obsidian Edge',
#  'Dagger',
#  'Recurve Bow',
#  'Amplifying Tome',
#  'Vampiric Scepter',
#  "Doran's Shield",
#  "Doran's Blade",
#  "Doran's Ring",
#  'Negatron Cloak',
#  'Needlessly Large Rod',
#  'Dark Seal',
#  'Cull',
#  'Scorchclaw Pup',
#  'Gustwalker Hatchling',
#  'Mosstomper Seedling',
#  'Eye of the Herald',
#  'Penetrating Bullets',
#  'Fortification',
#  'Reinforced Armor',
#  "Warden's Eye",
#  'Vanguard',
#  'Lightning Rod',
#  'Reinforced Armor',
#  'Overcharged',
#  'Anti-tower Socks',
#  'Gusto',
#  'Phreakish Gusto',
#  'Super Mech Armor',
#  'Super Mech Power Field',
#  'Turret Plating',
#  'Structure Bounty',
#  'Structure Bounty',
#  'Structure Bounty',
# ...

# %%
from urllib.request import urlretrieve
  for idx in lst:
    urlretrieve("http://ddragon.leagueoflegends.com/cdn/13.3.1/img/item/{}.png".format(idx), '/content/drive/MyDrive/4주프로젝트/item_img/{}'.format(idx))

# %%
from urllib.request import urlretrieve
urlretrieve("https://ddragon.leagueoflegends.com/cdn/13.3.1/img/item/3068.png", '/content/drive/MyDrive/4주프로젝트/item_img/3068')
# Out:
# ('/content/drive/MyDrive/4주프로젝트/item_img/3068',
#  <http.client.HTTPMessage at 0x7fb84197d400>)

# %% [markdown]
# # 룬사진가져오기

# %%
import json
with open('/content/perk.json', 'r') as f:
  lun_json = json.load(f)

# %%
len(lun_json)
# Out:
# 5

# %%
# 지배 domination
lun_json[0].keys()
# Out:
# dict_keys(['id', 'key', 'icon', 'name', 'slots'])

# %%
for i in range(5):
  print(lun_json[i]['name'])
# Out:
# Domination
# Inspiration
# Precision
# Resolve
# Sorcery

# %%
len(lun_json[0]['slots'])
# Out:
# 4

# %%
len(lun_json[0]['slots'][0]['runes'])
# Out:
# 4

# %%
# 감전 Electrocute
lun_json[0]['slots'][0]['runes'][0]
# Out:
# {'id': 8112,
#  'key': 'Electrocute',
#  'icon': 'perk-images/Styles/Domination/Electrocute/Electrocute.png',
#  'name': 'Electrocute',
#  'shortDesc': "Hitting a champion with 3 <b>separate</b> attacks or abilities in 3s deals bonus <lol-uikit-tooltipped-keyword key='LinkTooltip_Description_AdaptiveDmg'>adaptive damage</lol-uikit-tooltipped-keyword>.",
#  'longDesc': "Hitting a champion with 3 <b>separate</b> attacks or abilities within 3s deals bonus <lol-uikit-tooltipped-keyword key='LinkTooltip_Description_AdaptiveDmg'><font color='#48C4B7'>adaptive damage</font></lol-uikit-tooltipped-keyword>.<br><br>Damage: 30 - 180 (+0.4 bonus AD, +0.25 AP) damage.<br><br>Cooldown: 25 - 20s<br><br><hr><i>'We called them the Thunderlords, for to speak of their lightning was to invite disaster.'</i>"}

# %%
lun_json[0]['slots'][0]['runes'][0]['name']
# Out:
# 'Electrocute'

# %%
lun = []
for a in range(5):
  for b in range(len(lun_json[a]['slots'])):
    for c in range(len(lun_json[a]['slots'][b]['runes'])):
      lun.append(lun_json[a]['slots'][b]['runes'][c]['icon'])

lun
# Out:
# ['perk-images/Styles/Domination/Electrocute/Electrocute.png',
#  'perk-images/Styles/Domination/Predator/Predator.png',
#  'perk-images/Styles/Domination/DarkHarvest/DarkHarvest.png',
#  'perk-images/Styles/Domination/HailOfBlades/HailOfBlades.png',
#  'perk-images/Styles/Domination/CheapShot/CheapShot.png',
#  'perk-images/Styles/Domination/TasteOfBlood/GreenTerror_TasteOfBlood.png',
#  'perk-images/Styles/Domination/SuddenImpact/SuddenImpact.png',
#  'perk-images/Styles/Domination/ZombieWard/ZombieWard.png',
#  'perk-images/Styles/Domination/GhostPoro/GhostPoro.png',
#  'perk-images/Styles/Domination/EyeballCollection/EyeballCollection.png',
#  'perk-images/Styles/Domination/TreasureHunter/TreasureHunter.png',
#  'perk-images/Styles/Domination/IngeniousHunter/IngeniousHunter.png',
#  'perk-images/Styles/Domination/RelentlessHunter/RelentlessHunter.png',
#  'perk-images/Styles/Domination/UltimateHunter/UltimateHunter.png',
# ...

# %%
import os
os.mkdir('/content/drive/MyDrive/4주프로젝트/lun_img')

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from urllib.request import urlretrieve
# Domination Inspiration Precision Resolve Sorcery

for l,i in zip(lun, range(len(lun))):
  urlretrieve("https://ddragon.leagueoflegends.com/cdn/img/{}".format(l), '/content/drive/MyDrive/4주프로젝트/lun_img/lun{}'.format(i))

# %% [markdown]
# # 스펠사진가져오기

# %%
import json
with open('/content/spell.json', 'r') as f:
  spell_json = json.load(f)

# %%
spell_json['data'].keys()
# Out:
# dict_keys(['SummonerBarrier', 'SummonerBoost', 'SummonerDot', 'SummonerExhaust', 'SummonerFlash', 'SummonerHaste', 'SummonerHeal', 'SummonerMana', 'SummonerPoroRecall', 'SummonerPoroThrow', 'SummonerSmite', 'SummonerSnowURFSnowball_Mark', 'SummonerSnowball', 'SummonerTeleport', 'Summoner_UltBookPlaceholder', 'Summoner_UltBookSmitePlaceholder'])

# %%
import os
os.mkdir('/content/drive/MyDrive/4주프로젝트/spell_img')

# %%
from urllib.request import urlretrieve
for s in spell_json['data'].keys():
  urlretrieve("http://ddragon.leagueoflegends.com/cdn/13.3.1/img/spell/{}.png".format(s), '/content/drive/MyDrive/4주프로젝트/spell_img/{}'.format(s))
